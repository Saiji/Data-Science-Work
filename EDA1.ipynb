# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiji/Data-Science-Work/blob/master/EDA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Generate Professor Data for Practice.csv")

# %%
df.head()
# Out:
#                  Name                 Rank  Experience  Age  Salary
# 0     Dr. James Smith            Professor          25   58  165000
# 1   Dr. Linda Johnson  Associate Professor          14   46  115000
# 2     Robert Williams  Assistant Professor           4   32   78000
# 3  Dr. Patricia Brown            Professor          30   62  185000
# 4      Jennifer Jones  Assistant Professor           2   29   71000

# %%
df
# Out:
#                     Name                 Rank  Experience  Age  Salary
# 0        Dr. James Smith            Professor          25   58  165000
# 1      Dr. Linda Johnson  Associate Professor          14   46  115000
# 2        Robert Williams  Assistant Professor           4   32   78000
# 3     Dr. Patricia Brown            Professor          30   62  185000
# 4         Jennifer Jones  Assistant Professor           2   29   71000
# ..                   ...                  ...         ...  ...     ...
# 95    Dr. Theresa Butler            Professor          23   56  161000
# 96    Dr. Denise Simmons  Associate Professor          13   47  113500
# 97      Alexander Foster  Assistant Professor           6   36   86500
# 98  Dr. Marilyn Gonzales            Professor          29   62  183000
# 99      Dr. Julia Bryant  Associate Professor          15   51  120500
#
# [100 rows x 5 columns]

# %%
df.dtypes
# Out:
# Name          object
# Rank          object
# Experience     int64
# Age            int64
# Salary         int64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['Name', 'Rank', 'Experience', 'Age', 'Salary'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 500

# %%
df.shape
# Out:
# (100, 5)

# %%
df.values
# Out:
# array([['Dr. James Smith', 'Professor', 25, 58, 165000],
#        ['Dr. Linda Johnson', 'Associate Professor', 14, 46, 115000],
#        ['Robert Williams', 'Assistant Professor', 4, 32, 78000],
#        ['Dr. Patricia Brown', 'Professor', 30, 62, 185000],
#        ['Jennifer Jones', 'Assistant Professor', 2, 29, 71000],
#        ['Dr. Michael Garcia', 'Associate Professor', 12, 44, 108000],
#        ['Dr. Elizabeth Miller', 'Professor', 21, 54, 152000],
#        ['David Davis', 'Assistant Professor', 5, 33, 82000],
#        ['Dr. Mary Rodriguez', 'Associate Professor', 16, 49, 121000],
#        ['Dr. William Martinez', 'Professor', 28, 60, 178000],
#        ['Dr. Barbara Hernandez', 'Associate Professor', 11, 43, 105000],
#        ['Richard Lopez', 'Assistant Professor', 3, 31, 75000],
#        ['Dr. Susan Gonzalez', 'Professor', 23, 56, 159000],
#        ['Joseph Wilson', 'Assistant Professor', 6, 35, 85000],
#        ['Dr. Margaret Anderson', 'Associate Professor', 13, 47, 112000],
#        ['Dr. Charles Thomas', 'Professor', 26, 59, 169000],
#        ['Dr. Dorothy Taylor', 'Associate Professor', 15, 48, 118000],
#        ['Christopher Moore', 'Assistant Professor', 4, 32, 79000],
#        ['Dr. Karen Jackson', 'Professor', 22, 55, 155000],
#        ['Dr. Nancy Martin', 'Associate Professor', 10, 42, 102000],
#        ['Daniel Lee', 'Assistant Professor', 7, 36, 88000],
#        ['Dr. Betty Perez', 'Professor', 29, 61, 181000],
#        ['Dr. Lisa Thompson', 'Associate Professor', 17, 50, 124000],
#        ['Matthew White', 'Assistant Professor', 2, 30, 73000],
#        ['Dr. Sandra Harris', 'Professor', 24, 57, 162000],
#        ['Dr. Ashley Sanchez', 'Associate Professor', 12, 45, 110000],
#        ['Mark Clark', 'Assistant Professor', 5, 34, 83000],
#        ['Dr. Donna Ramirez', 'Professor', 27, 60, 174000],
#        ['Dr. Carol Lewis', 'Associate Professor', 14, 47, 116000],
#        ['Steven Robinson', 'Assistant Professor', 3, 32, 76000],
#        ['Dr. Michelle Walker', 'Professor', 21, 53, 151000],
#        ['Dr. Emily Young', 'Associate Professor', 11, 44, 106000],
#        ['Andrew Hall', 'Assistant Professor', 6, 37, 87000],
#        ['Dr. Sarah Allen', 'Professor', 31, 64, 190000],
#        ['Dr. Kimberly King', 'Associate Professor', 16, 51, 123000],
#        ['Joshua Wright', 'Assistant Professor', 4, 33, 80000],
#        ['Dr. Jessica Scott', 'Professor', 25, 58, 166000],
#        ['Dr. Laura Torres', 'Associate Professor', 13, 46, 113000],
#        ['Kevin Nguyen', 'Assistant Professor', 5, 34, 84000],
#        ['Dr. Brian Hill', 'Professor', 22, 54, 156000],
#        ['Dr. Amy Flores', 'Associate Professor', 15, 49, 119000],
#        ['Edward Green', 'Assistant Professor', 2, 29, 72000],
#        ['Dr. Ronald Adams', 'Professor', 28, 61, 177000],
#        ['Dr. Cynthia Nelson', 'Associate Professor', 10, 41, 101000],
#        ['Ronald Baker', 'Assistant Professor', 7, 38, 89000],
#        ['Dr. Angela Hall', 'Professor', 26, 59, 170000],
#        ['Dr. Kathleen Rivera', 'Associate Professor', 12, 45, 109000],
#        ['George Campbell', 'Assistant Professor', 4, 33, 81000],
#        ['Dr. Deborah Mitchell', 'Professor', 32, 65, 195000],
#        ['Dr. Alice Carter', 'Associate Professor', 17, 52, 126000],
#        ['Dr. Justin Roberts', 'Professor', 20, 52, 148000],
#        ['Dr. Megan Gomez', 'Associate Professor', 11, 43, 107000],
#        ['Jason Phillips', 'Assistant Professor', 5, 34, 84500],
#        ['Dr. Stephanie Evans', 'Professor', 24, 56, 163000],
#        ['Dr. Rebecca Turner', 'Associate Professor', 14, 48, 117000],
#        ['Jeffrey Parker', 'Assistant Professor', 3, 31, 77000],
#        ['Dr. Sharon Collins', 'Professor', 27, 60, 175000],
#        ['Dr. Cynthia Edwards', 'Associate Professor', 13, 47, 114000],
#        ['Ryan Stewart', 'Assistant Professor', 6, 36, 86000],
#        ['Dr. Nicole Morris', 'Professor', 23, 55, 160000],
#        ['Dr. Katherine Rogers', 'Associate Professor', 15, 50, 120000],
#        ['Gary Reed', 'Assistant Professor', 4, 32, 79500],
#        ['Dr. Amy Cook', 'Professor', 29, 62, 182000],
#        ['Dr. Shirley Morgan', 'Associate Professor', 12, 44, 111000],
#        ['Nicholas Bell', 'Assistant Professor', 2, 30, 74000],
#        ['Dr. Christine Murphy', 'Professor', 25, 58, 167000],
#        ['Dr. Catherine Bailey', 'Associate Professor', 11, 42, 104000],
#        ['Eric Rivera', 'Assistant Professor', 5, 35, 83500],
#        ['Dr. Diane Cooper', 'Professor', 30, 63, 188000],
#        ['Dr. Alice Richardson', 'Associate Professor', 16, 51, 122000],
#        ['Stephen Cox', 'Assistant Professor', 3, 32, 76500],
#        ['Dr. Janet Howard', 'Professor', 21, 54, 153000],
#        ['Dr. Julie Ward', 'Associate Professor', 14, 47, 115500],
#        ['Larry Peterson', 'Assistant Professor', 7, 39, 91000],
#        ['Dr. Joyce Gray', 'Professor', 26, 59, 171000],
#        ['Dr. Victoria James', 'Associate Professor', 13, 46, 112500],
#        ['Justin Watson', 'Assistant Professor', 4, 33, 80500],
#        ['Dr. Kelly Brooks', 'Professor', 24, 57, 164000],
#        ['Dr. Christina Kelly', 'Associate Professor', 10, 41, 102500],
#        ['Scott Sanders', 'Assistant Professor', 5, 34, 82500],
#        ['Dr. Joan Price', 'Professor', 28, 61, 179000],
#        ['Dr. Evelyn Bennett', 'Associate Professor', 15, 50, 119500],
#        ['Brandon Wood', 'Assistant Professor', 2, 29, 73500],
#        ['Dr. Martha Barnes', 'Professor', 22, 55, 157000],
#        ['Dr. Judith Ross', 'Associate Professor', 12, 45, 108500],
#        ['Gregory Henderson', 'Assistant Professor', 6, 37, 87500],
#        ['Dr. Cheryl Coleman', 'Professor', 31, 64, 192000],
#        ['Dr. Megan Jenkins', 'Associate Professor', 17, 52, 125000],
#        ['Samuel Perry', 'Assistant Professor', 4, 33, 81500],
#        ['Dr. Andrea Powell', 'Professor', 25, 58, 168000],
#        ['Dr. Hannah Long', 'Associate Professor', 11, 43, 106500],
#        ['Benjamin Patterson', 'Assistant Professor', 5, 34, 85500],
#        ['Dr. Jacqueline Hughes', 'Professor', 27, 60, 176000],
#        ['Dr. Beverly Flores', 'Associate Professor', 14, 48, 116500],
#        ['Patrick Washington', 'Assistant Professor', 3, 31, 77500],
#        ['Dr. Theresa Butler', 'Professor', 23, 56, 161000],
#        ['Dr. Denise Simmons', 'Associate Professor', 13, 47, 113500],
#        ['Alexander Foster', 'Assistant Professor', 6, 36, 86500],
#        ['Dr. Marilyn Gonzales', 'Professor', 29, 62, 183000],
#        ['Dr. Julia Bryant', 'Associate Professor', 15, 51, 120500]],
#       dtype=object)

# %%
df.size
# Out:
# 500

# %%
df.columns
# Out:
# Index(['Name', 'Rank', 'Experience', 'Age', 'Salary'], dtype='object')

# %%
df.dtypes
# Out:
# Name          object
# Rank          object
# Experience     int64
# Age            int64
# Salary         int64
# dtype: object

# %%
df.shape
# Out:
# (100, 5)

# %%
df.shape[0]
# Out:
# 100

# %%
df.shape[1]
# Out:
# 5

# %%
df.describe()
# Out:
#        Experience         Age         Salary
# count  100.000000  100.000000     100.000000
# mean    14.670000   46.360000  122255.000000
# std      9.097735   10.743586   37840.140557
# min      2.000000   29.000000   71000.000000
# 25%      6.000000   35.750000   85875.000000
# 50%     13.500000   47.000000  114500.000000
# 75%     23.000000   56.000000  160250.000000
# max     32.000000   65.000000  195000.000000

# %%
df.sample(10)
# Out:
#                     Name                 Rank  Experience  Age  Salary
# 71      Dr. Janet Howard            Professor          21   54  153000
# 1      Dr. Linda Johnson  Associate Professor          14   46  115000
# 50    Dr. Justin Roberts            Professor          20   52  148000
# 17     Christopher Moore  Assistant Professor           4   32   79000
# 98  Dr. Marilyn Gonzales            Professor          29   62  183000
# 42      Dr. Ronald Adams            Professor          28   61  177000
# 93    Dr. Beverly Flores  Associate Professor          14   48  116500
# 5     Dr. Michael Garcia  Associate Professor          12   44  108000
# 82          Brandon Wood  Assistant Professor           2   29   73500
# 61             Gary Reed  Assistant Professor           4   32   79500

# %%
df.describe()
# Out:
#        Experience         Age         Salary
# count  100.000000  100.000000     100.000000
# mean    14.670000   46.360000  122255.000000
# std      9.097735   10.743586   37840.140557
# min      2.000000   29.000000   71000.000000
# 25%      6.000000   35.750000   85875.000000
# 50%     13.500000   47.000000  114500.000000
# 75%     23.000000   56.000000  160250.000000
# max     32.000000   65.000000  195000.000000

# %%
df.max()
# Out:
# Name          Steven Robinson
# Rank                Professor
# Experience                 32
# Age                        65
# Salary                 195000
# dtype: object

# %%
df.min()
# Out:
# Name             Alexander Foster
# Rank          Assistant Professor
# Experience                      2
# Age                            29
# Salary                      71000
# dtype: object

# %%
df.Experience.std()
# Out:
# 9.097735315933733

# %%
df.describe()
# Out:
#        Experience         Age         Salary
# count  100.000000  100.000000     100.000000
# mean    14.670000   46.360000  122255.000000
# std      9.097735   10.743586   37840.140557
# min      2.000000   29.000000   71000.000000
# 25%      6.000000   35.750000   85875.000000
# 50%     13.500000   47.000000  114500.000000
# 75%     23.000000   56.000000  160250.000000
# max     32.000000   65.000000  195000.000000

# %%
df.count()
# Out:
# Name          100
# Rank          100
# Experience    100
# Age           100
# Salary        100
# dtype: int64

# %%
df.head()
# Out:
#                  Name                 Rank  Experience  Age  Salary
# 0     Dr. James Smith            Professor          25   58  165000
# 1   Dr. Linda Johnson  Associate Professor          14   46  115000
# 2     Robert Williams  Assistant Professor           4   32   78000
# 3  Dr. Patricia Brown            Professor          30   62  185000
# 4      Jennifer Jones  Assistant Professor           2   29   71000

# %%
df.describe()
# Out:
#        Experience         Age         Salary
# count  100.000000  100.000000     100.000000
# mean    14.670000   46.360000  122255.000000
# std      9.097735   10.743586   37840.140557
# min      2.000000   29.000000   71000.000000
# 25%      6.000000   35.750000   85875.000000
# 50%     13.500000   47.000000  114500.000000
# 75%     23.000000   56.000000  160250.000000
# max     32.000000   65.000000  195000.000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['Experience'].mean()
# Out:
# np.float64(14.67)

# %%
df.head(50)
# Out:
#                      Name                 Rank  Experience  Age  Salary
# 0         Dr. James Smith            Professor          25   58  165000
# 1       Dr. Linda Johnson  Associate Professor          14   46  115000
# 2         Robert Williams  Assistant Professor           4   32   78000
# 3      Dr. Patricia Brown            Professor          30   62  185000
# 4          Jennifer Jones  Assistant Professor           2   29   71000
# 5      Dr. Michael Garcia  Associate Professor          12   44  108000
# 6    Dr. Elizabeth Miller            Professor          21   54  152000
# 7             David Davis  Assistant Professor           5   33   82000
# 8      Dr. Mary Rodriguez  Associate Professor          16   49  121000
# 9    Dr. William Martinez            Professor          28   60  178000
# 10  Dr. Barbara Hernandez  Associate Professor          11   43  105000
# 11          Richard Lopez  Assistant Professor           3   31   75000
# 12     Dr. Susan Gonzalez            Professor          23   56  159000
# 13          Joseph Wilson  Assistant Professor           6   35   85000
# 14  Dr. Margaret Anderson  Associate Professor          13   47  112000
# 15     Dr. Charles Thomas            Professor          26   59  169000
# 16     Dr. Dorothy Taylor  Associate Professor          15   48  118000
# 17      Christopher Moore  Assistant Professor           4   32   79000
# 18      Dr. Karen Jackson            Professor          22   55  155000
# 19       Dr. Nancy Martin  Associate Professor          10   42  102000
# 20             Daniel Lee  Assistant Professor           7   36   88000
# 21        Dr. Betty Perez            Professor          29   61  181000
# 22      Dr. Lisa Thompson  Associate Professor          17   50  124000
# 23          Matthew White  Assistant Professor           2   30   73000
# 24      Dr. Sandra Harris            Professor          24   57  162000
# 25     Dr. Ashley Sanchez  Associate Professor          12   45  110000
# 26             Mark Clark  Assistant Professor           5   34   83000
# 27      Dr. Donna Ramirez            Professor          27   60  174000
# 28        Dr. Carol Lewis  Associate Professor          14   47  116000
# 29        Steven Robinson  Assistant Professor           3   32   76000
# 30    Dr. Michelle Walker            Professor          21   53  151000
# 31        Dr. Emily Young  Associate Professor          11   44  106000
# 32            Andrew Hall  Assistant Professor           6   37   87000
# 33        Dr. Sarah Allen            Professor          31   64  190000
# 34      Dr. Kimberly King  Associate Professor          16   51  123000
# 35          Joshua Wright  Assistant Professor           4   33   80000
# 36      Dr. Jessica Scott            Professor          25   58  166000
# 37       Dr. Laura Torres  Associate Professor          13   46  113000
# 38           Kevin Nguyen  Assistant Professor           5   34   84000
# 39         Dr. Brian Hill            Professor          22   54  156000
# 40         Dr. Amy Flores  Associate Professor          15   49  119000
# 41           Edward Green  Assistant Professor           2   29   72000
# 42       Dr. Ronald Adams            Professor          28   61  177000
# 43     Dr. Cynthia Nelson  Associate Professor          10   41  101000
# 44           Ronald Baker  Assistant Professor           7   38   89000
# 45        Dr. Angela Hall            Professor          26   59  170000
# 46    Dr. Kathleen Rivera  Associate Professor          12   45  109000
# 47        George Campbell  Assistant Professor           4   33   81000
# 48   Dr. Deborah Mitchell            Professor          32   65  195000
# 49       Dr. Alice Carter  Associate Professor          17   52  126000

# %%
df.dtypes
# Out:
# Name          object
# Rank          object
# Experience     int64
# Age            int64
# Salary         int64
# dtype: object

# %%
df.describe()
# Out:
#        Experience         Age         Salary
# count  100.000000  100.000000     100.000000
# mean    14.670000   46.360000  122255.000000
# std      9.097735   10.743586   37840.140557
# min      2.000000   29.000000   71000.000000
# 25%      6.000000   35.750000   85875.000000
# 50%     13.500000   47.000000  114500.000000
# 75%     23.000000   56.000000  160250.000000
# max     32.000000   65.000000  195000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        100 non-null    object
#  1   Rank        100 non-null    object
#  2   Experience  100 non-null    int64
#  3   Age         100 non-null    int64
#  4   Salary      100 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.0+ KB

# %%
df.head()
# Out:
#                  Name                 Rank  Experience  Age  Salary
# 0     Dr. James Smith            Professor          25   58  165000
# 1   Dr. Linda Johnson  Associate Professor          14   46  115000
# 2     Robert Williams  Assistant Professor           4   32   78000
# 3  Dr. Patricia Brown            Professor          30   62  185000
# 4      Jennifer Jones  Assistant Professor           2   29   71000

# %%
df.Experience
# Out:
# 0     25
# 1     14
# 2      4
# 3     30
# 4      2
#       ..
# 95    23
# 96    13
# 97     6
# 98    29
# 99    15
# Name: Experience, Length: 100, dtype: int64

# %%
df['Experience']
# Out:
# 0     25
# 1     14
# 2      4
# 3     30
# 4      2
#       ..
# 95    23
# 96    13
# 97     6
# 98    29
# 99    15
# Name: Experience, Length: 100, dtype: int64

# %%
df[['Experience']]
# Out:
#     Experience
# 0           25
# 1           14
# 2            4
# 3           30
# 4            2
# ..         ...
# 95          23
# 96          13
# 97           6
# 98          29
# 99          15
#
# [100 rows x 1 columns]

# %%
df.describe()
# Out:
#        Experience         Age         Salary
# count  100.000000  100.000000     100.000000
# mean    14.670000   46.360000  122255.000000
# std      9.097735   10.743586   37840.140557
# min      2.000000   29.000000   71000.000000
# 25%      6.000000   35.750000   85875.000000
# 50%     13.500000   47.000000  114500.000000
# 75%     23.000000   56.000000  160250.000000
# max     32.000000   65.000000  195000.000000

# %%
df.Experience.count()
# Out:
# np.int64(100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        100 non-null    object
#  1   Rank        100 non-null    object
#  2   Experience  100 non-null    int64
#  3   Age         100 non-null    int64
#  4   Salary      100 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.0+ KB

# %%
df.head()
# Out:
#                  Name                 Rank  Experience  Age  Salary
# 0     Dr. James Smith            Professor          25   58  165000
# 1   Dr. Linda Johnson  Associate Professor          14   46  115000
# 2     Robert Williams  Assistant Professor           4   32   78000
# 3  Dr. Patricia Brown            Professor          30   62  185000
# 4      Jennifer Jones  Assistant Professor           2   29   71000

# %%
df_Rank=df.groupby('Rank')

# %%
# df_Rank.mean('Experiance', 'Age', 'Salary')
df_Rank.max()
# Out:
#                                      Name  Experience  Age  Salary
# Rank
# Assistant Professor       Steven Robinson           7   39   91000
# Associate Professor    Dr. Victoria James          17   52  126000
# Professor            Dr. William Martinez          32   65  195000
